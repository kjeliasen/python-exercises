# %% [markdown]
# # Exercises

# %% [markdown]
# Do your work for this exercise in a jupyter notebook named `4.6.1_matplotlib_exercises`.

# %%
import matplotlib.pyplot as plt
import matplotlib.units as units
import matplotlib.ticker as ticker

import math
import numpy as np

# %%
xvals = [round(x, 1) for x in np.arange(-6, 6.01, .1)]
yvals = [round(abs(x), 2) for x in xvals]

#fig1, ax1 = plt.subplots()
p1 = plt.plot(xvals, yvals, c='b')
#print('setp(p1):')
#print(plt.setp(p1))
#print('setp(p1.axes)')
#plt.setp(p1.Axes)



plt.show()

# %% [markdown]
# 1) Use matplotlib to plot the following equation:
#
# - $y = x^2 − x + 2$
#
# Add an anotation for the point 0, 0, the origin.

# %%
plt.show()

xvals1 = [round(x, 1) for x in np.arange(-6, 6.01, .1)]
yvals1 = [round(x ** 2 - x + 2, 2) for x in xvals1]

fig1, ax1 = plt.subplots()
plt.axes(xlim=(-4.5,5), ylim=(-5,25))
plt.plot(xvals1, yvals1, c='b')
#plt.axis([-4.5,5.5,-5,25])

ax1.title=('$y = x^2 - x + 2$')
plt.annotate('(0, 0)', xy=(0, 0), xytext=(1,-5), arrowprops={'facecolor': 'b', 'shrink': .15})


#plt.xlim=(-4.5, 5.5)
#plt.ylim=(-5,25)



ax1.spines['left'].set_position('zero')
ax1.spines['bottom'].set_position('zero')
ax1.spines['top'].set_color('none')
ax1.spines['right'].set_color('none')

#plt.title=('hello')

plt.show()

# %% [markdown]
# 2) Create and label 4 separate charts for the following equations (choose a range for x that makes sense):
#
# - $y = √ x$
# - $y = x^3$
# - $y = tan(x)$
# - $y = 2 x$
#
#
# You can use functions from the math module to help implement some of the equations above.

# %%
xvals2a = [round(x, 1) for x in np.arange(0, 26.01, .1)]
yvals2a = [round(x ** .5, 2) for x in xvals2a]

fig2a, ax2a = plt.subplots()
ax2a.plot(xvals2a, yvals2a, c='b')
plt.suptitle('$y = \sqrt{x}$')

plt.xlim=(-1, 25.5)
plt.ylim=(-.5,5.5)

ax2a.spines['left'].set_position('zero')
ax2a.spines['bottom'].set_position('zero')
ax2a.spines['top'].set_color('none')
ax2a.spines['right'].set_color('none')

plt.show()

# %%
xvals2b = [round(x, 1) for x in np.arange(-5, 5.01, .1)]
yvals2b = [round(x ** 3, 2) for x in xvals2b]

fig2b, ax2b = plt.subplots(figsize=(5,10))
plt.plot(xvals2b, yvals2b, c='b')
plt.title=('$y = \sqrt{x}$')
#plt.figure(figsize=(1,2))
plt.xlim=(-5.5, 5.5)
plt.ylim=(-25,25)
plt.grid=(True)
plt.Axes

ax2b.spines['left'].set_position('zero')
ax2b.spines['bottom'].set_position('zero')
ax2b.spines['top'].set_color('none')
ax2b.spines['right'].set_color('none')

plt.show()

# %%
xvals2c = [round(x, 1) for x in np.arange(-2 * math.pi, 2 * math.pi +.0001, .01 * math.pi)]
yvals2c = [round(math.tan(x), 2) for x in xvals2c]

fig2c, ax2c = plt.subplots()
ax2c.plot(xvals2c, yvals2c, c='b')
plt.suptitle('$y = tan(x)$')

plt.xlim=(-7, 7)
plt.ylim=(-5,5)

ax2c.spines['left'].set_position('zero')
ax2c.spines['bottom'].set_position('zero')
ax2c.spines['top'].set_color('none')
ax2c.spines['right'].set_color('none')

plt.show()

# %%
xvals2d = [round(x, 1) for x in np.arange(0, 25.01, .1)]
yvals2d = [round(x * 2, 2) for x in xvals2d]

fig2d, ax2d = plt.subplots()
ax2d.plot(xvals2d, yvals2d, c='b')
plt.suptitle('$y = 2x$')

plt.xlim(-4.5, 5.5)
plt.ylim(-5,25)

ax2d.spines['left'].set_position('zero')
ax2d.spines['bottom'].set_position('zero')
ax2d.spines['top'].set_color('none')
ax2d.spines['right'].set_color('none')

plt.show()

# %% [markdown]
# 3) Combine the figures you created in the last step into one large figure with 4 subplots.

# %%
plt.subplot(221)

xvals1 = [round(x, 1) for x in np.arange(-6, 6.01, .1)]
yvals1 = [round(x ** 2 - x + 2, 2) for x in xvals1]

#fig1, ax1 = plt.subplots()
plt.plot(xvals1, yvals1, c='b')

plt.title = ('$y = x^2 - x + 2$')
#plt.annotate('(0, 0)', xy=(0, 0), xytext=(1,-5), arrowprops={'facecolor': 'b', 'shrink': .15})

plt.xlim = (-4.5, 5.5)
plt.ylim = (-5,25)

#ax1.spines['left'].set_position('zero')
#ax1.spines['bottom'].set_position('zero')
#ax1.spines['top'].set_color('none')
#ax1.spines['right'].set_color('none')

plt.subplot(222)

xvals2b = [round(x, 1) for x in np.arange(-5, 5.01, .1)]
yvals2b = [round(x ** 3, 2) for x in xvals2b]

#fig2b, ax2b = plt.subplots(figsize=(5,10))
plt.plot(xvals2b, yvals2b, c='b')
plt.title = ('$y = \sqrt{x}$')
#plt.figure(figsize=(1,2))
plt.xlim = (-5.5, 5.5)
plt.ylim = (-25,25)

#ax2b.spines['left'].set_position('zero')
#ax2b.spines['bottom'].set_position('zero')
#ax2b.spines['top'].set_color('none')
#ax2b.spines['right'].set_color('none')

plt.subplot(223)

xvals2c = [round(x, 1) for x in np.arange(-2 * math.pi, 2 * math.pi +.0001, .01 * math.pi)]
yvals2c = [round(math.tan(x), 2) for x in xvals2c]

#fig2c, ax2c = plt.subplots()
plt.plot(xvals2c, yvals2c, c='b')
plt.title = ('$y = tan(x)$')

ax2c.xlim = (-7, 7)
ax2c.ylim = (-5,5)

#ax2c.spines['left'].set_position('zero')
#ax2c.spines['bottom'].set_position('zero')
#ax2c.spines['top'].set_color('none')
#ax2c.spines['right'].set_color('none')

plt.subplot(224)

xvals2d = [round(x, 1) for x in np.arange(-25, 25.01, .1)]
yvals2d = [round(x * 2, 2) for x in xvals2d]

#fig2d, ax2d = plt.subplots()
plt.plot(xvals2d, yvals2d, c='b')
plt.title = ('$y = 2x$')

plt.xlim = (-4.5, 5.5)
plt.ylim = (-5,25)

#ax2d.spines['left'].set_position('zero')
#ax2d.spines['bottom'].set_position('zero')
#ax2d.spines['top'].set_color('none')
#ax2d.spines['right'].set_color('none')

plt.show()

# %% [markdown]
# 4) Comine the figures you created in the last step into one figure where each of the 4 equations has a different color for the points. Be sure to include a legend.

# %% [markdown]
# ### Bonus
# Write the code necessary to write your name on a chart. Use box letters.
#
# ### Bonus:
# use curves for letters in your name that have curves in them.
