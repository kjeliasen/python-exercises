# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

# %%
np.random.seed(123)

students = ['Sally', 'Jane', 'Suzie', 'Billy', 'Ada', 'John', 'Thomas',
            'Marie', 'Albert', 'Richard', 'Isaac', 'Alan']

# randomly generate scores for each student for each subject
# note that all the values need to have the same length here
math_grades = np.random.randint(low=60, high=100, size=len(students))
english_grades = np.random.randint(low=60, high=100, size=len(students))
reading_grades = np.random.randint(low=60, high=100, size=len(students))

df = pd.DataFrame({'name': students,
                   'math': math_grades,
                   'english': english_grades,
                   'reading': reading_grades,
                   'classroom': np.random.choice(['A', 'B'], len(students))})
df['passing_math'] = df.math.apply(lambda n: 'passing' if n >= 70 else 'failing')

# %%
from pydataset import data
tips = data('tips')

# %%
sns.relplot(data=df, x='math',y='english')
plt.title('Example seaborn viz')
plt.show()

# %%
sns.relplot(data=df,x='math',y='english',hue='passing_math',style='classroom')
plt.show()

# %%
sns.distplot(df.math)
plt.show()

# %%
sns.boxplot(data=df,x='math')
plt.show()

# %%
sns.boxplot(data=df,y='math',x='classroom')
plt.show()

# %%
sns.boxplot(data=df,y='math',x='classroom',hue='passing_math')
plt.hlines(df.math.median(), -1, 2, ls=':')
plt.text(1.75,df.math.median()+1,'{}'.format(df.math.median()))
plt.show()

# %%
sns.boxplot(data=tips, y='total_bill', x='size', hue='smoker')
plt.show()

# %%
df.corr()
print(df.corr())
sns.heatmap(df.corr(), annot=True, cmap='Reds', robust=False)
plt.show()
# Out:
#              math   english   reading
# math     1.000000 -0.151234 -0.060959
# english -0.151234  1.000000  0.335586
# reading -0.060959  0.335586  1.000000

# %%
sns.heatmap(pd.crosstab(tips['size'], tips.smoker))
plt.show()

# %%
sns.jointplot(data=df, x='reading', y='english')
plt.show()

# %%
sns.pairplot(data=df)
plt.show()

# %%
pt = tips.pivot_table('total_bill', 'size', ['smoker', 'time'])
print(pt)
# Out:
# smoker         No                   Yes
# time       Dinner      Lunch     Dinner      Lunch
# size
# 1        7.250000  10.070000   3.070000   8.580000
# 2       16.062143  14.156765  18.589583  16.265556
# 3       21.252609  19.146667  30.312000  17.590000
# 4       27.647391  28.703333  30.340000  31.820000
# 5       25.270000  41.190000  29.305000        NaN
# 6       48.170000  30.383333        NaN        NaN

# %%
#tips?

# %%
#sns.heatmap(pd.crosstab(pt['smoker'], [pt.smoker]))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'smoker'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-65-deab221b76f7> in <module>
# ----> 1 sns.heatmap(pd.crosstab(pt['smoker'], [pt.smoker]))
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2924         if is_single_key:
#    2925             if self.columns.nlevels > 1:
# -> 2926                 return self._getitem_multilevel(key)
#    2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_multilevel(self, key)
#    2970
#    2971     def _getitem_multilevel(self, key):
# -> 2972         loc = self.columns.get_loc(key)
#    2973         if isinstance(loc, (slice, Series, np.ndarray, Index)):
#    2974             new_columns = self.columns[loc]
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/multi.py in get_loc(self, key, method)
#    2395
#    2396         if not isinstance(key, tuple):
# -> 2397             loc = self._get_level_indexer(key, level=0)
#    2398             return _maybe_to_slice(loc)
#    2399
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/multi.py in _get_level_indexer(self, key, level, indexer)
#    2650         else:
#    2651
# -> 2652             code = level_index.get_loc(key)
#    2653
#    2654             if level > 0 or self.lexsort_depth == 0:
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'smoker'
